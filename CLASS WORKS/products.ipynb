# %%
class sportMart:
    def __init__(self):
        self.inventory = {}
        self.orders = {}
        
    def createOrder(self,Orderid,ItemName,Quantity,Price,Total):
        temp = {
            "orderid": Orderid,
            "itemname": ItemName,
            "quantity": Quantity,
            "price": Price,
            "total": Total
        }
        
        self.orders[Orderid] = temp
        
    def createInventory(self,ProductID,ProductName,Quantity,Price):
        temp = {
            "productid": ProductID,
            "productname": ProductName,
            "quantity": Quantity,
            "price": Price
        }
        
        self.inventory[ProductID] = temp
        
    def printOrders(self):
        print(self.orders)
        
    def printInventory(self):
        print(self.inventory)
        
    def updateInventory(self):
        print(self.inventory)
        

trinity = sportMart()


orders = open("orders.csv","r")
orders_header = orders.readline()
orders_orders = orders.readlines()
for item in orders_orders:
    temp = item.strip().split(',')
    trinity.createOrder(temp[0],temp[1],temp[2],temp[3],temp[4])
    
    trinity.printOrders()
    
    
inventory = open("inventory.csv","r")
inventory_header = inventory.readline()
inventory_inventory = inventory.readlines()
for item in inventory_inventory:
    temp = item.strip().split(',')
    trinity.createInventory(temp[0],temp[1],temp[2],temp[3])
    
    trinity.printInventory()
    
# create a menu driven program that will 
# --> create new orders and update the inventory accordingly
# --> export the final data to the file    

# while True:
#     print("Menu Options")
#     print("1. Create new orders")
#     print("2. Update Inventory")
#     print("3. Exit")
    
#     choice = input("Enter the choice").strip()
#     if choice == "1":
        
#     elif choice == "2":
        
#     elif choice == "3":
#         exit()
#     else:
#         print("Invalid Choice")
# Out:
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}, 'OD0004': {'orderid': 'OD0004', 'itemname': 'Stumps', 'quantity': '9', 'price': '6200', 'total': '55800'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}, 'OD0004': {'orderid': 'OD0004', 'itemname': 'Stumps', 'quantity': '9', 'price': '6200', 'total': '55800'}, 'OD0005': {'orderid': 'OD0005', 'itemname': 'Football', 'quantity': '4', 'price': '9500', 'total': '38000'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}, 'OD0004': {'orderid': 'OD0004', 'itemname': 'Stumps', 'quantity': '9', 'price': '6200', 'total': '55800'}, 'OD0005': {'orderid': 'OD0005', 'itemname': 'Football', 'quantity': '4', 'price': '9500', 'total': '38000'}, 'OD0006': {'orderid': 'OD0006', 'itemname': 'Basketball', 'quantity': '1', 'price': '5000', 'total': '5000'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}, 'OD0004': {'orderid': 'OD0004', 'itemname': 'Stumps', 'quantity': '9', 'price': '6200', 'total': '55800'}, 'OD0005': {'orderid': 'OD0005', 'itemname': 'Football', 'quantity': '4', 'price': '9500', 'total': '38000'}, 'OD0006': {'orderid': 'OD0006', 'itemname': 'Basketball', 'quantity': '1', 'price': '5000', 'total': '5000'}, 'OD0007': {'orderid': 'OD0007', 'itemname': 'Chess', 'quantity': '8', 'price': '600', 'total': '4800'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}, 'OD0004': {'orderid': 'OD0004', 'itemname': 'Stumps', 'quantity': '9', 'price': '6200', 'total': '55800'}, 'OD0005': {'orderid': 'OD0005', 'itemname': 'Football', 'quantity': '4', 'price': '9500', 'total': '38000'}, 'OD0006': {'orderid': 'OD0006', 'itemname': 'Basketball', 'quantity': '1', 'price': '5000', 'total': '5000'}, 'OD0007': {'orderid': 'OD0007', 'itemname': 'Chess', 'quantity': '8', 'price': '600', 'total': '4800'}, 'OD0008': {'orderid': 'OD0008', 'itemname': 'Ball', 'quantity': '9', 'price': '730', 'total': '6570'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}, 'OD0004': {'orderid': 'OD0004', 'itemname': 'Stumps', 'quantity': '9', 'price': '6200', 'total': '55800'}, 'OD0005': {'orderid': 'OD0005', 'itemname': 'Football', 'quantity': '4', 'price': '9500', 'total': '38000'}, 'OD0006': {'orderid': 'OD0006', 'itemname': 'Basketball', 'quantity': '1', 'price': '5000', 'total': '5000'}, 'OD0007': {'orderid': 'OD0007', 'itemname': 'Chess', 'quantity': '8', 'price': '600', 'total': '4800'}, 'OD0008': {'orderid': 'OD0008', 'itemname': 'Ball', 'quantity': '9', 'price': '730', 'total': '6570'}, 'OD0009': {'orderid': 'OD0009', 'itemname': 'Tennis', 'quantity': '2', 'price': '450', 'total': '900'}}
# {'OD0001': {'orderid': 'OD0001', 'itemname': 'Bat', 'quantity': '2', 'price': '1000', 'total': '2000'}, 'OD0002': {'orderid': 'OD0002', 'itemname': 'Ball', 'quantity': '5', 'price': '500', 'total': '2500'}, 'OD0003': {'orderid': 'OD0003', 'itemname': 'Batminton', 'quantity': '6', 'price': '700', 'total': '4200'}, 'OD0004': {'orderid': 'OD0004', 'itemname': 'Stumps', 'quantity': '9', 'price': '6200', 'total': '55800'}, 'OD0005': {'orderid': 'OD0005', 'itemname': 'Football', 'quantity': '4', 'price': '9500', 'total': '38000'}, 'OD0006': {'orderid': 'OD0006', 'itemname': 'Basketball', 'quantity': '1', 'price': '5000', 'total': '5000'}, 'OD0007': {'orderid': 'OD0007', 'itemname': 'Chess', 'quantity': '8', 'price': '600', 'total': '4800'}, 'OD0008': {'orderid': 'OD0008', 'itemname': 'Ball', 'quantity': '9', 'price': '730', 'total': '6570'}, 'OD0009': {'orderid': 'OD0009', 'itemname': 'Tennis', 'quantity': '2', 'price': '450', 'total': '900'}, 'OD0010': {'orderid': 'OD0010', 'itemname': 'Volleyball', 'quantity': '7', 'price': '530', 'total': '3710'}}
# {'PID001': {'productid': 'PID001', 'productname': 'Bat', 'quantity': '2', 'price': '1000'}}
# {'PID001': {'productid': 'PID001', 'productname': 'Bat', 'quantity': '2', 'price': '1000'}, 'PID002': {'productid': 'PID002', 'productname': 'Ball', 'quantity': '5', 'price': '5000'}}
# {'PID001': {'productid': 'PID001', 'productname': 'Bat', 'quantity': '2', 'price': '1000'}, 'PID002': {'productid': 'PID002', 'productname': 'Ball', 'quantity': '5', 'price': '5000'}, 'PID003': {'productid': 'PID003', 'productname': 'Batminton Racket', 'quantity': '7', 'price': '450'}}
# {'PID001': {'productid': 'PID001', 'productname': 'Bat', 'quantity': '2', 'price': '1000'}, 'PID002': {'productid': 'PID002', 'productname': 'Ball', 'quantity': '5', 'price': '5000'}, 'PID003': {'productid': 'PID003', 'productname': 'Batminton Racket', 'quantity': '7', 'price': '450'}, 'PID004': {'productid': 'PID004', 'productname': 'Stumps', 'quantity': '9', 'price': '741'}}
# {'PID001': {'productid': 'PID001', 'productname': 'Bat', 'quantity': '2', 'price': '1000'}, 'PID002': {'productid': 'PID002', 'productname': 'Ball', 'quantity': '5', 'price': '5000'}, 'PID003': {'productid': 'PID003', 'productname': 'Batminton Racket', 'quantity': '7', 'price': '450'}, 'PID004': {'productid': 'PID004', 'productname': 'Stumps', 'quantity': '9', 'price': '741'}, 'PID005': {'productid': 'PID005', 'productname': 'Baseball', 'quantity': '3', 'price': '955'}}
# {'PID001': {'productid': 'PID001', 'productname': 'Bat', 'quantity': '2', 'price': '1000'}, 'PID002': {'productid': 'PID002', 'productname': 'Ball', 'quantity': '5', 'price': '5000'}, 'PID003': {'productid': 'PID003', 'productname': 'Batminton Racket', 'quantity': '7', 'price': '450'}, 'PID004': {'productid': 'PID004', 'productname': 'Stumps', 'quantity': '9', 'price': '741'}, 'PID005': {'productid': 'PID005', 'productname': 'Baseball', 'quantity': '3', 'price': '955'}, 'PID006': {'productid': 'PID006', 'productname': 'Football', 'quantity': '5', 'price': '260'}}
# {'PID001': {'productid': 'PID001', 'productname': 'Bat', 'quantity': '2', 'price': '1000'}, 'PID002': {'productid': 'PID002', 'productname': 'Ball', 'quantity': '5', 'price': '5000'}, 'PID003': {'productid': 'PID003', 'productname': 'Batminton Racket', 'quantity': '7', 'price': '450'}, 'PID004': {'productid': 'PID004', 'productname': 'Stumps', 'quantity': '9', 'price': '741'}, 'PID005': {'productid': 'PID005', 'productname': 'Baseball', 'quantity': '3', 'price': '955'}, 'PID006': {'productid': 'PID006', 'productname': 'Football', 'quantity': '5', 'price': '260'}, 'PID007': {'productid': 'PID007', 'productname': 'Cricket', 'quantity': '2', 'price': '3650'}}
